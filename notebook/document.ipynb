# %% [markdown]
# Data Ingestion

# %%
### Document datastructure

from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source":"exmaple.txt",
        "pages":1,
        "author":"Sham",
        "date_created":"2025-01-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'exmaple.txt', 'pages': 1, 'author': 'Krish Naik', 'date_created': '2025-01-01'}, page_content='this is the main text content I am using to create RAG')

# %%
## Create a simple txt file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
### TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# C:\Users\7860s\AppData\Local\Temp\ipykernel_13436\2416650908.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", ## Pattern to match files  
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False

)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ## Pattern to match files  
    loader_cls= PyMuPDFLoader, ##loader class to use
    show_progress=False

)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'LibreOffice 24.2', 'creator': 'Writer', 'creationdate': '2026-06-05T00:29:14+05:30', 'source': '..\\data\\pdf\\Ahatesham_Resume.pdf', 'file_path': '..\\data\\pdf\\Ahatesham_Resume.pdf', 'total_pages': 1, 'format': 'PDF 1.7', 'title': '', 'author': 'Arbaz Hundekar', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20260605002914+05'30'", 'page': 0}, page_content='Ahatesham Mopagar\nPhone: +91 7892466068\nLinkedIn:-www.linkedin.com/in/ahatesham-mopagar-398288224\nGitHub:- https://github.com/Ahatesham121\nEmail: 7860sham@gmail.com\n•\nPython Programming with Data Structures and Algorithm and Object Oriented Programming Concepts.\n•\nDeployed Restful web application using FASTAPI as the backend framework and MySQL as the relational database system.\n\uf0b7\nSkills: Python, C++, Microsoft Power BI, MySQL, Lang Chain. Lang Graph, Data Structures and Algorithm, \nObject Oriented Programming.\nCybersecurity simulation\nDeloitte\nJune 2025 – July 2025\n•\nCompleted a job simulation involving reading web activity logs.\n•\nSupported a client in a cyber security breach.\n•\nAnswered questions to identify suspicious user activity.\n     Cybersecurity Analyst\nHackers10\nApril 2025 – May2025 \n•\n Web application Pentesting.\n•\n  Network Pentesting.\n•\n  SOCIAL ENGINEERING & PHISHING SIMULATION. \n•\n  Malware Analysis, Reverse Engineering & Threat Hunting. \n•\n  Cloud Security Audits. \n \n      Security Analyst Intern\nThe Red Users\nMAY 2024 - Jun 2024\n•\n Python programming for Cyber Security.\n•\nExploring wifi Security Exploring flipper zero in Cybersecurity.\n•\nSecurity Information and event management(SIEM).\n•\nInstall, configure and manage security tools. \nSkills: Python, MySQL, Burp suite.\n      Software Developer Intern\nFriends Union Energizing Lives\nSEP 2023 - NOV 2023\n•\nBasic Python Programing With AI.\n•\nData Structures and Algorithm.\n•\nDesign Restful web application using FASTAPI as the backend framework and MySQL as the relational database \nsystem.\nSkills: Python, MySQL, Fast API, Docker, SQL Alchemy.\nPROJECTS\nMobile Application Vulnerability\nJAN 2024\n•\nIt is a software tool that scans android apk and performs Static Analysis for Vulnerability Assessment generates \nReport after each scan which includes information about threats that apk file can have. The is implemented on local \nhost server mangoDB as database.\n•\nSkills: Python, MongoDB, MySQL, Lang Graph.\nAI Agent Using Lang Chain and Lang Graph\nDEC 2024\n•\nAi agent cable answering Question by using Natural Language Understanding.\n•\nSkills: Python with Lang Chain and Lang Graph, OpenAI API Key, SQL Alchemy.\nBuild Fast API App with MySQL Database\n•\nThis project involves the development of a Restful web application using FASTAPI as the \nbackend framework and MySQL as the relational database system.\n•\nThe application is designed to handle CRUD operations (Create, Read, Update, Delete) \nthrough a high-performance, asynchronous API.\n•\nSkills:- Python, Fast API , Uvicorn, My SQL, SQL Alchemy.\nAcademics\nFEB 2025\n•\nQualification: B.E in Computer Science and Engineering from Visveswaraya Technological University In 2024 \nwith Overall CGPA 7.8.\n•\nCourse Work: Operating Systems, Computer Programming, Database, Cybersecurity and Networks.\n•\nCertifications: Certified Ethical Hacker V13 From EC Council.'),
#  Document(metadata={'producer': 'jsPDF 2.5.1', 'creator': '', 'creationdate': '2025-09-29T16:58:25+05:30', 'source': '..\\data\\pdf\\Ahateshm resume (1).pdf', 'file_path': '..\\data\\pdf\\Ahateshm resume (1).pdf', 'total_pages': 2, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20250929165825+05'30'", 'page': 0}, page_content='Ahatesham Mopagar\nACADEMIC DETAILS\nSECAB Institute of Engineering and Technology, Bijapur\n2024\n (CLASS \nXII) \nExcellent Pu Science College\n2020\n (CLASS X) \nKendriya Vidyalaya Vijayapura\n2018\nComputer Science & \nEngineering\nB.E.\n76 %\nKarnataka Secondary \nEducation Examination \nBoard (KSEEB)\n68 %\nCBSE\n69 %\nSUBJECTS\nTechnical Proficiency\nWeb Application Security,Networking,Python3,Networking Concepts,Network Security,SQL \nProgramming,C++,Android Testing,Artificial Intelligence,CSS,HTML5\nWORK EXPERIENCE\nINTERNSHIPS\nCybersecurity  Analyst \nInternship\nWeb application Pentesting. \nNetwork Pentesting. \nSOCIAL ENGINEERING & PHISHING SIMULATION. \nMalware Analysis,Reverse Engineering & Threat Hunting. \nCloud Security Audits\nApr 2025\n-\nMay 2025\nCybersecurity  Analyst \nInternship\nPython programing for cyber Security\nExploring wifi SecurityExploring flipper zero in cybersecurity.\nSecurity Information and event management(SIEM).\nInstall, configure and manage security tools.\nSep 2024\n-\nNov 2024\nSoftware Developer Intern\nBasic Python Programing With AI\nData Structures and Algorithm\nJava Programing Language\nAug 2023\n-\nSep 2023\nHackers 10\nThe Red Users (Self)\nFUEL\nPROJECTS\nThis report documents the penetration testing performed on "testphp.vulnweb.com" as part\nof XYZ Company\'s ethical hacking internship. The objective was to identify security\nvulnerabilities within the application and provide recommendations for mitigation.\nTechniques Used\n• Information Gathering (Reconnaissance)\n• Cross-Site Scripting (XSS)\nTools and Frameworks Utilized\n• OWASP ZAP- (automated vulnerability scanning tool)\n• Kali Linux – (Operating system)\n• Nmap- (network scanner)\nApr 2025\n-\nMay 2025\nAi agent cable answering Question by using Natural Language Understanding.\nSkills: Python with Lang Chain and Lang Graph, OpenAI API Key, SQL Alchemy.\nNov 2024\n-\nJan 2025\nIt is a software tool that scans android apk and performs Static Analysis for Vulnerability \nAssessment generates Report \nD\n2023\nWeb Application Security \nTesting\n•\n•\n•\nAI Agent Using Lang Cha\nin and Lang Graph\n•\n•\n•'),
#  Document(metadata={'producer': 'jsPDF 2.5.1', 'creator': '', 'creationdate': '2025-09-29T16:58:25+05:30', 'source': '..\\data\\pdf\\Ahateshm resume (1).pdf', 'file_path': '..\\data\\pdf\\Ahateshm resume (1).pdf', 'total_pages': 2, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20250929165825+05'30'", 'page': 1}, page_content='BASIC INFORMATION\nMobile Number: 7892466068\nAddress: Behind Mehtar Mahal Jammia \nMasjid Road Vijayapur, Bijapur(KAR),\nBijapur(KAR), Karnataka - 586101\nEmail: 7860sham@gmail.com\nafter each scan which includes information about threats that apk file can have. The is \nimplemented on local host server\nmangoDB as database.\n Skills: Python, MongoDB, MySQL, Lang Graphaa\nDec 2023\n-\nFeb 2024\nMobile Application Vulne\nrability Scanner \n•\n•\n•\nCONFERENCES AND WORKSHOPS\nVOLUNTEER EXPERIENCE\nRole: Volunteer\nCause: Social Services\nCaring Souls india Charitable Trust bagged the best Ngo working at the grass root level of North \nKarnataka  with its effective programmes and projects  especially \n1.pensions schemes \n2.women empowerment \n3.Girl child education \n4.Medical support for old people .\nThe award is presented by Dwani and the heads of Azim Premji foundation and Dwani \nfoundation    \nat Bangalore  recently\nJan 2022\n-\nPresent\nCaring Souls India \nCharitable Trust \nLANGUAGES\nKannada, English, Hindi')]

# %%
### TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
